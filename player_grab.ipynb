# %%
import requests
import os
import sqlite3
import time
import pandas as pd
from riotwatcher import LolWatcher

# %%
conn = sqlite3.connect('C:\sqlite\lol.db') 
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE IF NOT EXISTS match_data (
        tier TEXT,
        rank TEXT,
        summonerId TEXT,
        summonerName TEXT,
        leaguePoints INTEGER,
        wins INTEGER,
        losses INTEGER,
        veteran TEXT,
        inactive TEXT,
        freshBlood TEXT,
        hotStreak TEXT,
        puuid TEXT,
        PRIMARY KEY (summonerId, puuid)
    )
''')

# %%
api_key = ''
lol_watcher = LolWatcher(api_key)
queue = 'RANKED_SOLO_5x5'
regions = ['na1', 'euw1', 'eun1', 'kr', 'br1', 'tr1', 'la1', 'la2', 'oc1', 'jp1']

# %%
top_players_csv = 'top_players.csv'

df_topplayers_all_regions = []

def get_top_players_ranked5x5(region, queue, api_key, cursor):
    assert queue in ['RANKED_SOLO_5x5', 'RANKED_FLEX_SR', 'RANKED_FLEX_TT']

    total_users_to_insert = list()

    # Endpoints for challenger, grandmaster, and master tier players
    request_urls = [
        f'https://{region}.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/{queue}',
        f'https://{region}.api.riotgames.com/lol/league/v4/grandmasterleagues/by-queue/{queue}',
        f'https://{region}.api.riotgames.com/lol/league/v4/masterleagues/by-queue/{queue}'
    ]

    # HTTP header to make requests to Riot API
    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:96.0) Gecko/20100101 Firefox/96.0",
        "Accept-Language": "en-US,en;q=0.9",
        "Accept-Charset": "utf-8",
        "Origin": "https://developer.riotgames.com",
        "X-Riot-Token": api_key
    }

    for x in request_urls:
        response = requests.get(x, headers=headers)
        if response.status_code == 200:
            try:
                print('Name: {} | Region: {} | Tier: {} | Queue: {} | Total Players: {}'.format(
                    response.json()['name'], region, response.json()['tier'], response.json()['queue'], len(response.json()['entries'])))
            except KeyError as e:
                pass
            for y in response.json()['entries']:
                try:
                    y['tier'] = response.json()['tier']
                    y['request_region'] = region
                    y['queue'] = queue

                    # API rate limits
                    time.sleep(1.2)

                    summoner_encrypted = lol_watcher.summoner.by_id(region, y['summonerId'])
                    y['puuid'] = summoner_encrypted['puuid']
                    total_users_to_insert.append(y)
                except KeyError as e:
                    pass

        else:
            print('Request error (@elite). HTTP code {}: {}'.format(response.status_code, response.json()))
            continue

    df_topplayers = pd.DataFrame(total_users_to_insert, columns=['tier', 'rank', 'summonerId', 
    'summonerName', 'leaguePoints', 'wins', 'losses', 'veteran', 'inactive', 'freshBlood', 'hotStreak', 'puuid'])

    df_topplayers['region'] = region

    print('Total users obtained in region {} and queue {}: {}'.format(region, queue, len(total_users_to_insert)))
    print(df_topplayers.head(5))

    df_topplayers_all_regions.append(df_topplayers)

    df_topplayers.to_csv(f'topplayers_{region}.csv', index = False)
    print(f'CSV file saved for {region} region')

    df_topplayers.to_sql('match_data', conn, if_exists = 'replace', index = False)

    conn.commit()

# %%
# Iterate through regions and fetch match data
for region in regions:
    get_top_players_ranked5x5(region, queue, api_key, cursor)

# Concatenate DataFrames from all regions
df_topplayers_all_regions_combined = pd.concat(df_topplayers_all_regions, ignore_index=True)

# Save the overall DataFrame to the main CSV file
df_topplayers_all_regions_combined.to_csv('topplayers.csv', index=False)
print(f"Main CSV file saved to: {os.path.abspath('topplayers.csv')}")

# Close the database connection
conn.close()
# Out:
# Name: LeBlanc's Hunters | Region: na1 | Tier: CHALLENGER | Queue: RANKED_SOLO_5x5 | Total Players: 5
# Name: Amumu's Commandos | Region: na1 | Tier: GRANDMASTER | Queue: RANKED_SOLO_5x5 | Total Players: 89
# Name: Twisted Fate's Shadows | Region: na1 | Tier: MASTER | Queue: RANKED_SOLO_5x5 | Total Players: 995
# Total users obtained in region na1 and queue RANKED_SOLO_5x5: 1089
#          tier rank                                         summonerId  \
# 0  CHALLENGER    I   mhLLqroOptAU2ZU67hzBcJWOgp8_UCiXwl7-s7fjAElD1WZe
# 1  CHALLENGER    I    QHRI5njQodt5aesgDHQl4R_kIfI1VeQtMdNnBCRsdhA_kpg
# 2  CHALLENGER    I    KPdFHgBkSBJ7XbzunN24XporbIKWt4dJYEFBiQGNnoQgxiU
# 3  CHALLENGER    I    ewCfTMmgdXdwlBx4kl2KTVf-O-pAsVNA338m_kY2shXk9S4
# 4  CHALLENGER    I  agKQE14_19PZ1T-JvEKw0nhCJ22wLleweql3UKu194SBMd...
#
#     summonerName  leaguePoints  wins  losses  veteran  inactive  freshBlood  \
# 0       WanBieJi           501    71      41    False     False        True
# 1         Spica9           506    53      34    False     False        True
# 2     YouAllSuck           661    70      36    False     False        True
# 3          Cupic           689    53      24    False     False        True
# 4  Jiang duo bao           639    58      35    False     False        True
#
#    hotStreak                                              puuid region
# 0       True  3ll1PPV0dJo5SPE6A7d2ugsLrLnTh5eRJRW_1Ymx-EDoBe...    na1
# 1      False  r524bPm8r4aCEMDAaWEAC1Y4v1VF54NIR1_q0cJJVigKBs...    na1
# 2      False  8hGybXqbiICB7DwwmwCFqV9Vqi4GEm8ETCl8Apafusj7bh...    na1
# 3      False  0WdCaVu093PtF7eoR14VfxZOwTudlwYE-a23eWuZ_BzT1Q...    na1
# 4       True  KoeqUmvyi8Whv42XjASj-WZ2qaodjih5GLU1oQMs79IPX5...    na1
# CSV file saved for na1 region
# Name: Nami's Alliance | Region: euw1 | Tier: CHALLENGER | Queue: RANKED_SOLO_5x5 | Total Players: 7
# Name: Garen's Archons | Region: euw1 | Tier: GRANDMASTER | Queue: RANKED_SOLO_5x5 | Total Players: 143
# Name: Urgot's Corruptors | Region: euw1 | Tier: MASTER | Queue: RANKED_SOLO_5x5 | Total Players: 1999
# Total users obtained in region euw1 and queue RANKED_SOLO_5x5: 2149
#          tier rank                                        summonerId  \
# 0  CHALLENGER    I   m5VUMltB9BfHbOCvgLT_9xRmBbaY9KXC0watpHl-8UmP09s
# 1  CHALLENGER    I  btPRI8ML_mAzDd3cKg1W-gY1Jjp7KDY-p4U3yNGRIgo-WPk_
# 2  CHALLENGER    I   FrfnE2j5yaUuB32UgOXtwiQ_s-maqamD-zgM66rwZixk20k
# 3  CHALLENGER    I  XJaRpDhMdwIJeJ9MIH4LGn_LtGsbvpVJjq5g-0BBJ-97Zei_
# 4  CHALLENGER    I  UCQ2nW28gqKilTHytx7_t21WuzwvT0zrXpEFe92LKtyRn6HB
#
#   summonerName  leaguePoints  wins  losses  veteran  inactive  freshBlood  \
# 0     Lathyrus           675    72      50    False     False        True
# 1     cadianNN           509    47      23    False     False        True
# 2     Sinerias           523    75      47    False     False        True
# 3  q t u hgd v           608    56      30    False     False        True
# 4        Qnoxs           698    76      56    False     False        True
#
#    hotStreak                                              puuid region
# 0       True  DAJvvti1TmtNom__sNwvxHo6o3fzgxAebiSCb0LDUyNh4D...   euw1
# 1       True  zIY37Lr6JO1zg_zz0fJAIiQZ3RSWr2_TY_R8bW6iqnPSba...   euw1
# 2       True  joe6tM5c1PAdWiwPS5GKl-XJAZTM1eO2ZFb_4rJwxaigxh...   euw1
# 3      False  OIBmFjq6bbdkIGwiedDyLjiwY4FaoUJJWI8bUaryTZ3Xkb...   euw1
# 4      False  C4fDSPqmg60I4x-JXT-88Sm1da7j1hWC0sWHjkZSZ0etWt...   euw1
# CSV file saved for euw1 region
# Name: Malphite's Paladins | Region: eun1 | Tier: CHALLENGER | Queue: RANKED_SOLO_5x5 | Total Players: 13
# Name: Ezreal's Weaponmasters | Region: eun1 | Tier: GRANDMASTER | Queue: RANKED_SOLO_5x5 | Total Players: 63
# Name: Taric's Wizards | Region: eun1 | Tier: MASTER | Queue: RANKED_SOLO_5x5 | Total Players: 991
# Total users obtained in region eun1 and queue RANKED_SOLO_5x5: 1067
#          tier rank                                         summonerId  \
# 0  CHALLENGER    I    -xFIx0yjIGCCNbQWLq6aT6sUmZPFkq0RuY9IbSBrrv83FPc
# 1  CHALLENGER    I    iL1M5OlVt41x9s6XZI7-9RQFVcPkU__DYpCPOuerhHkqfRQ
# 2  CHALLENGER    I    dYWvSxrnqAMWHE7TvF2n88KSxuNLkWz9T5RYjp3DgXczzxo
# 3  CHALLENGER    I  tgwpNSdFf7QNuKxbDvr-aR5QherpDV0cgVfirvmnZr9a17...
# 4  CHALLENGER    I    wz7xTRKhfkouYuAvzMw2CmwGTBo6F--UzSirBWbKVARmOcw
#
#       summonerName  leaguePoints  wins  losses  veteran  inactive  freshBlood  \
# 0  judgement night           514    50      24    False     False        True
# 1                            499    57      37    False     False        True
# 2        XiaoTaoQi           677    79      59    False     False        True
# 3         annoying           512    88      63    False     False        True
# 4    Vayne Helsing           574    52      19    False     False        True
#
#    hotStreak                                              puuid region
# 0      False  XOOHoofeoTDb-XNJgZrY9b8abqYNrVyHXnBw5xLGY58LVZ...   eun1
# 1      False  8FWm1k-SstPIPLnFaWQTJppSgSBYmhbq6QH7dvD6YDIZDn...   eun1
# 2       True  -qPdZE1i51vDr6UktVfRBWk9S39Ux_ABe5cxqyaQUqTLG0...   eun1
# 3       True  EQsW3PGBo-HFu9dBxyDxAKiEdLYSgmHIkL0Fbn84vxN3zv...   eun1
# 4      False  jAv44JH9oOywk0QkItgW_5yu_VjLiLflZKvlZBxKVD0qjk...   eun1
# CSV file saved for eun1 region
# Name: Sona's Sentinels | Region: kr | Tier: CHALLENGER | Queue: RANKED_SOLO_5x5 | Total Players: 7
# Name: Yorick's Duelists | Region: kr | Tier: GRANDMASTER | Queue: RANKED_SOLO_5x5 | Total Players: 100
# Name: Irelia's Blackguards | Region: kr | Tier: MASTER | Queue: RANKED_SOLO_5x5 | Total Players: 1521
# Total users obtained in region kr and queue RANKED_SOLO_5x5: 1628
#          tier rank                                         summonerId  \
# 0  CHALLENGER    I    9L9WqymIwr_daS5hpPWXh_VYEq4Cq8vRHrsD_FnBehlQhws
# 1  CHALLENGER    I    L0ZX6-MGom8R_VsyOkZAU93uZnDRlhV6qAVS6RYEOBbccls
# 2  CHALLENGER    I    5zCJqzIYpH3vSksB---Qsg1eOJiLQSpVajJmvMSZ1l3i65Q
# 3  CHALLENGER    I  2upmAZbE8jGpTPZR9hVFhTbD4-ev-hBjJgomf8A-lP0Tm3...
# 4  CHALLENGER    I  PHHX9c0WxW8ZLM26agzbL-rIL7fUiKKKGzPRvRoc2xXnvs...
#
#    summonerName  leaguePoints  wins  losses  veteran  inactive  freshBlood  \
# 0    bababaabam           519    94      74    False     False        True
# 1        FA ady           553    96      83    False     False        True
# 2         디케이 탑           694    75      50    False     False        True
# 3  Hao tian Jug           575    97      62    False     False        True
# 4     aowamzosq           594    93      71    False     False        True
#
#    hotStreak                                              puuid region
# 0       True  vabpWsNvDBvKOi1faLr_GoA_T2-ddfIqWaSsInIy5nUT-0...     kr
# 1       True  XRe7uo4mkoigiS2PxjZd6NaZUZSuKrQdIP4jm5KJqWX1rA...     kr
# 2       True  s9-BvXnjzr-ccFIEBgjQ7m2HnbgjWOBbtoIOhhBbFKoyfY...     kr
# 3      False  uwe2T_lJDQuIxlNtdQN5Cbldnmf2gi7sv3ecUn6DJrAdCi...     kr
# 4      False  yv5dREZMmnHj7XgHA8RYL4aSYKG6Y66RGD-PB97aLILTWK...     kr
# CSV file saved for kr region
# Name: Udyr's Alliance | Region: br1 | Tier: CHALLENGER | Queue: RANKED_SOLO_5x5 | Total Players: 10
# Name: Ahri's Scouts | Region: br1 | Tier: GRANDMASTER | Queue: RANKED_SOLO_5x5 | Total Players: 112
# Name: Leona's Host | Region: br1 | Tier: MASTER | Queue: RANKED_SOLO_5x5 | Total Players: 1246
# Total users obtained in region br1 and queue RANKED_SOLO_5x5: 1368
#          tier rank                                       summonerId  \
# 0  CHALLENGER    I   njDFPShpudyswBOrruEkATZ3p0UpVvTurKwvqQH87MzzMA
# 1  CHALLENGER    I  UPnOhmZQTA13cZM-A_lBuTuyO_reO-3c3XeC5mWisFwU-sE
# 2  CHALLENGER    I   dgcRln4U8M9BGbp8mXMWt-VGS1hTX45WwMdP0_DOSdP0zg
# 3  CHALLENGER    I  85u4iqcCB6N-XpldLqKp2BYdauUvrdsPeFkKOzdgk70h7bo
# 4  CHALLENGER    I  RzJae4FA1fvFxjTLnkjdgymvEFpPmN1f3ZuBpIJza942ONQ
#
#   summonerName  leaguePoints  wins  losses  veteran  inactive  freshBlood  \
# 0    tadeceboo           605    73      52    False     False        True
# 1     Yukarina           500    46      27    False     False        True
# 2       zzkeio           520    75      46    False     False        True
# 3      wellyck           512    44      13    False     False        True
# 4     Remorsos           563    87      70    False     False        True
#
#    hotStreak                                              puuid region
# 0      False  Mbnv4haWcmRducirKzaTg5EETxKry2IzecihbVW52j3C_9...    br1
# 1      False  fQSLr8UNbfLYmcEV5jKDGprch8mC5JWRQrRXeI2moGXKtn...    br1
# 2      False  1S1dslQo853dg3IkXoMX3622974J3cuBK2VlEeO1F7L8l3...    br1
# 3      False  0MLlipEz7Eo4Ep6r0sZiOOza21w6Cmwj1wQI8Krife_iDy...    br1
# 4       True  EORp_LQcZ4egTYmdHcEZD47zbOjLj-Uw5wdOkspLZNNzx5...    br1
# CSV file saved for br1 region
# Name: Jayce's Archons | Region: tr1 | Tier: CHALLENGER | Queue: RANKED_SOLO_5x5 | Total Players: 6
# Name: Sivir's Spellslingers | Region: tr1 | Tier: GRANDMASTER | Queue: RANKED_SOLO_5x5 | Total Players: 45
# Name: Evelynn's Demolishers | Region: tr1 | Tier: MASTER | Queue: RANKED_SOLO_5x5 | Total Players: 405
# Total users obtained in region tr1 and queue RANKED_SOLO_5x5: 456
#          tier rank                                         summonerId  \
# 0  CHALLENGER    I  obauNAFDKq0a5rz6zNZmjyoH0QLpEb7MUqm91K1EuclxND...
# 1  CHALLENGER    I  gpGe7SOxMzcXmjYVRpIwFRzMAush2yFyESiBL8w_MgchiQ...
# 2  CHALLENGER    I  -Xndvo6uSkJ6LQpT-nuKRRbLa0YuD-SBZFU64J4uvaZsos...
# 3  CHALLENGER    I  _AgSUZxn5Sk0YAtdKLN5WhlLlAvrsuzaOwDohFyPHKF8sK...
# 4  CHALLENGER    I  n2P3pnVx4wMQbbyDMg9STRf46F8T6pLtRsxJ__Cueik1ZN...
#
#      summonerName  leaguePoints  wins  losses  veteran  inactive  freshBlood  \
# 0                           510    41      17    False     False        True
# 1      dalgasın Æ           549    62      26    False     False        True
# 2  Remember Me DW           748    86      56    False     False        True
# 3        Xampiaro           509    58      30    False     False        True
# 4       CrawL4fun           703    59      27    False     False        True
#
#    hotStreak                                              puuid region
# 0      False  t16S8FFVt5U9v3Ib-DPM9-jgVoIr2konhIVInQBQoQPdjo...    tr1
# 1       True  VJ601Qe6v3VuTiQ_32DBe5s839qrt_PNcgFfqyti0JPpAH...    tr1
# 2      False  xn-Rp-FaKB0-N4Qy2p59VMzXyW5Q29NESOb8ztbWC1UrNy...    tr1
# 3       True  mHvfZptlLAmsMRXAOJUuAdbllVYyhjVxsoeqr3UafkaOj3...    tr1
# 4      False  eJyD_fjZb3lncRTD4s_VCtgZ9Yn2qdvWgU9w4xmyBaOooY...    tr1
# CSV file saved for tr1 region
# Name: Urgot's Gladiators | Region: la1 | Tier: CHALLENGER | Queue: RANKED_SOLO_5x5 | Total Players: 9
# Name: Fiora's Reapers | Region: la1 | Tier: GRANDMASTER | Queue: RANKED_SOLO_5x5 | Total Players: 48
# Name: Evelynn's Wraiths | Region: la1 | Tier: MASTER | Queue: RANKED_SOLO_5x5 | Total Players: 430
# Total users obtained in region la1 and queue RANKED_SOLO_5x5: 487
#          tier rank                                         summonerId  \
# 0  CHALLENGER    I  C0mFuKAojZR9tJYGHDyUV9cZFgrllJsleZ4Q6Qqpxd0LLn...
# 1  CHALLENGER    I     lUeT0ZFXt1DAIB7iiQXS6hnYG5Y0GeHvHbGbwOeJhlYdig
# 2  CHALLENGER    I    -TsKHtu45Uj3UJ-dpNT8uk07_vjvj9qpg1HANe2wAAqT2YA
# 3  CHALLENGER    I  PUSDNtAwwkyQSVPsCUjcd0SYGNyv86NS56NqI4aKVhFW3G...
# 4  CHALLENGER    I     qMhyXATj16Za2ntnxscFWhUbcBrx_-_PaDeqWm4W9kRZjA
#
#   summonerName  leaguePoints  wins  losses  veteran  inactive  freshBlood  \
# 0      Yasıkof           637    56      33    False     False        True
# 1        STEPZ           798    66      41    False     False        True
# 2     Charolon           518    61      46    False     False        True
# 3     Meguıtan           814    70      48    False     False        True
# 4         Hąwk           521    44      24    False     False        True
#
#    hotStreak                                              puuid region
# 0      False  K_nJetTtehvna8qOffqLSbNTaAd4BIfRuYsaljX9ChL3l7...    la1
# 1      False  QHk4Z28Yo5x4QLL2MM5cSGFxVJsdemVpiQk-kaX_YVm_Zi...    la1
# 2      False  V2emM1A5taPRD8pzz9Z-y0OHBH814PgPNCugOoGQPgxvWY...    la1
# 3      False  4ZdPTwIgvhxSe88D1lghDJuztjVvss54wVnSmiZab50nUk...    la1
# 4      False  GDWN4Q_vOqvjUThl0KDRqhMF6XVBs-e7dJ7vFwvnRC9nyQ...    la1
# CSV file saved for la1 region
# Name: Mordekaiser's Destroyers | Region: la2 | Tier: CHALLENGER | Queue: RANKED_SOLO_5x5 | Total Players: 3
# Name: Cassiopeia's Shadowdancers | Region: la2 | Tier: GRANDMASTER | Queue: RANKED_SOLO_5x5 | Total Players: 28
# Name: Draven's Elementalists | Region: la2 | Tier: MASTER | Queue: RANKED_SOLO_5x5 | Total Players: 308
# Total users obtained in region la2 and queue RANKED_SOLO_5x5: 339
#           tier rank                                       summonerId  \
# 0   CHALLENGER    I  H_OLh6F66AXlqj-ZYUAPETqbqM-4r2IHO1vAXjn0MysXfII
# 1   CHALLENGER    I     xIRgoZU3gx58-haSB9zZEi4W8rXpF7GY8Ljf2LjWh70h
# 2   CHALLENGER    I     qTrhQnHxzXvGoUyo-CcEtqJMkc-zzm13CgAqm0k5UPlW
# 3  GRANDMASTER    I      OkKsk0zyb3A2HHnmQMc52U_hq32tMeKbsSSEaUMGGZM
# 4  GRANDMASTER    I  CC1PPpvuPZLUPdhnq_MQT6SGDXx7-3vlS6Yyc_l0QSpf9kM
#
#      summonerName  leaguePoints  wins  losses  veteran  inactive  freshBlood  \
# 0       BWC LOVER           603    87      52    False     False        True
# 1  Renata Enjoyer           494    56      35    False     False        True
# 2         lautahz           535    71      50    False     False        True
# 3            Meju           215    34      18    False     False        True
# 4     Rengar King           309    45      30    False     False        True
#
#    hotStreak                                              puuid region
# 0      False  g4KZg-xCS0kwt9TxwCmeDnjotdo5BpmS2petLAIp0widWl...    la2
# 1      False  -K6mIFLDjD0v4rntcaKIJ7TV3-ZXYTRDHT2gag-aD5l_Ld...    la2
# 2       True  9P42nsFnGy7wRxMtwK8evqxaxfxuRGhzYP8G_z-XawP97R...    la2
# 3       True  H_IdS3Fwjy-T1fkGisE_E0D49F3zgDnwP_qFYoeumqVhYV...    la2
# 4      False  oxQr9erLqMbpnt2ftItZ0vuNg9KohX8d6S0mK7VylsUO67...    la2
# CSV file saved for la2 region
# Name: Yorick's Ravagers | Region: oc1 | Tier: CHALLENGER | Queue: RANKED_SOLO_5x5 | Total Players: 2
# Name: Irelia's Berserkers | Region: oc1 | Tier: GRANDMASTER | Queue: RANKED_SOLO_5x5 | Total Players: 21
# Name: Rammus's Elementalists | Region: oc1 | Tier: MASTER | Queue: RANKED_SOLO_5x5 | Total Players: 131
# Total users obtained in region oc1 and queue RANKED_SOLO_5x5: 154
#           tier rank                                         summonerId  \
# 0   CHALLENGER    I       GgdQXo6iqIdvJxoiEw20Q9UGwqTfDdTU-5ndgVY-Ucmc
# 1   CHALLENGER    I    hjeLp9SxqiZAsVKQMbvMhCCPgVl7hUPC7x7xzRqCJNLctvg
# 2  GRANDMASTER    I       bdNABHZntfK-IbBelJtSrXokU0YUs2QVxhv4eWoGhpDn
# 3  GRANDMASTER    I  m6_Y45P7FV_yZTZjfrWXpqprpQOdj6WS1GSH6Ri4ZPlils...
# 4  GRANDMASTER    I  THuhQCD7ff9PrbKuLyBtqL-U1NAcN-jXpgHHvf2V019scE...
#
#   summonerName  leaguePoints  wins  losses  veteran  inactive  freshBlood  \
# 0     zorenous           597    63      33    False     False        True
# 1         Ming           748    58      28    False     False        True
# 2        nox 1           401    49      35    False     False        True
# 3      Quofuka           217    84      49    False     False        True
# 4       Messes           276    52      39    False     False        True
#
#    hotStreak                                              puuid region
# 0      False  gxXI7isGNwI6Xc_lAxxJCuJX78jC4TJmd28cGY-bZaNN3m...    oc1
# 1      False  DGxLBcHx7KtSdlbb2rDvQ9n0Wuov35ZKZ9p2xWwaIwPUpH...    oc1
# 2      False  AeGl31z9H29RTHtUv8VQ5pdrSZyI8urObetBv7ovUfBcSu...    oc1
# 3      False  g67itFUDx-LiRRGBwUKpxTY7AnW9LJeusf8ZxnTTjMwDrg...    oc1
# 4      False  a5WVVqSy74Zv3XDjVTyuVx80l4bbmxClJatCMxXIPj4M2Z...    oc1
# CSV file saved for oc1 region
# Name: Malzahar's Brutes | Region: jp1 | Tier: CHALLENGER | Queue: RANKED_SOLO_5x5 | Total Players: 2
# Name: Akali's Tyrants | Region: jp1 | Tier: GRANDMASTER | Queue: RANKED_SOLO_5x5 | Total Players: 9
# Name: Cho'Gath's Demolishers | Region: jp1 | Tier: MASTER | Queue: RANKED_SOLO_5x5 | Total Players: 111
# Total users obtained in region jp1 and queue RANKED_SOLO_5x5: 122
#           tier rank                                         summonerId  \
# 0   CHALLENGER    I  -yUFO9wq8QpAuVY1aKHOu9M9SkkartNPRlsv1fZN-qGFl3...
# 1   CHALLENGER    I     BTP4cJYaybgnrpDpAJirpZSQZ-0BsOetK9Es3OdwN-L3tQ
# 2  GRANDMASTER    I     VhmcXdPgtqEl4i3HWirsvLrafp4gTe1ZbRzsFjff3z92tQ
# 3  GRANDMASTER    I  ppHhpuSR9CmwfMhWeR9eJlgwqoDDw7AraLwl4wCZtkA-7a...
# 4  GRANDMASTER    I  dtvPKdxV3cDcBI40hYIEE-XeNT71ltB1izsovjSaD200TF...
#
#        summonerName  leaguePoints  wins  losses  veteran  inactive  \
# 0                             635    45      18    False     False
# 1              Enty           686    73      62    False     False
# 2  WitchCraftSabbat           270    36      18    False     False
# 3      tiaolouzisha           320    55      40    False     False
# 4             凖透明少年           201    72      68    False     False
#
#    freshBlood  hotStreak                                              puuid  \
# 0        True       True  e5B6EozGrdYIKE4djL4mZ_OX2f5VWlLiWM3w0xYEXci6ms...
# 1        True       True  qRc7RuedhBuzbdJmdigP7IMBGUWqUTufziB9b7XgmBId7m...
# 2        True      False  gpQbmLY2LN84gDk9qoeELLAAzEzPGPSBag1dg2NfS1xli0...
# 3        True       True  _JMUNdPd_1uGVS5bo8nHJHp-6Z6lD9doBQqJoHGpFCM0Rl...
# 4        True      False  BEC7HFvfm6TCPTbpmYiygBEYySES80sDMGJpNq-gIyqrQA...
#
#   region
# 0    jp1
# 1    jp1
# 2    jp1
# 3    jp1
# 4    jp1
# CSV file saved for jp1 region
# Main CSV file saved to: /home/ismin/topplayers.csv
